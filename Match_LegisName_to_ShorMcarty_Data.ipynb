# %%
import pandas as pd
from fuzzywuzzy import process
from fuzzywuzzy import fuzz

# %%
# Import file with messy names
# This has data in only one column

file = "/Users/ishitagopal/Desktop/Letters.csv"

df = pd.read_csv(file,skipinitialspace=True)
df.head()
# Out:
#                                   ﻿Signatory
# 0            Senator Kevin Ranker Washington
# 1       Assemblyman Thomas Abinanti New York
# 2    Representative John Ager North Carolina
# 3               Senator Ben Allen California
# 4  Representative Sherry Appleton Washington

# %%
len(df)
# Out:
# 225

# %%
df.columns
# Out:
# Index(['﻿Signatory'], dtype='object')

# %%
# Rename the 'Signatory' column name to deal with white-space problem
# New name is 'Signing_Legis'

df['﻿Signatory']
df.rename(columns = {'﻿Signatory':'Signing_Legis'}, inplace= True)

# %%
# Dictionary of abbreviated state names 

State_Abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %%
# Split 'Signing_Legis' to remove the first word which contains the designation of the legislator
# Save it in 'Legis_Design'

df[['Legis_Design','Remaining_Data']] = df["Signing_Legis"].str.split(" ", 1, expand=True)
df.head()
# Out:
#                                Signing_Legis    Legis_Design  \
# 0            Senator Kevin Ranker Washington         Senator
# 1       Assemblyman Thomas Abinanti New York     Assemblyman
# 2    Representative John Ager North Carolina  Representative
# 3               Senator Ben Allen California         Senator
# 4  Representative Sherry Appleton Washington  Representative
#
#                Remaining_Data
# 0     Kevin Ranker Washington
# 1    Thomas Abinanti New York
# 2    John Ager North Carolina
# 3        Ben Allen California
# 4  Sherry Appleton Washington

# %%
# Save the state's name as an abbreveations in the column 'Legis_State'
# Save legislator's name in the column 'Legis_Name'

State_Codes = []
Names = []

for row in df["Remaining_Data"]:
    for key in State_Abbrev:
        if key in row:            
            Names.append(row.replace(key,'').strip())
            State_Codes.append(State_Abbrev[key])
            
df["Legis_Name"] = Names
df["Legis_State"] = State_Codes  

df.head()
# Out:
#                                Signing_Legis    Legis_Design  \
# 0            Senator Kevin Ranker Washington         Senator
# 1       Assemblyman Thomas Abinanti New York     Assemblyman
# 2    Representative John Ager North Carolina  Representative
# 3               Senator Ben Allen California         Senator
# 4  Representative Sherry Appleton Washington  Representative
#
#                Remaining_Data       Legis_Name Legis_State
# 0     Kevin Ranker Washington     Kevin Ranker          WA
# 1    Thomas Abinanti New York  Thomas Abinanti          NY
# 2    John Ager North Carolina        John Ager          NC
# 3        Ben Allen California        Ben Allen          CA
# 4  Sherry Appleton Washington  Sherry Appleton          WA

# %%
# Remove repetative information by droping the 'Remaining_Data' column 

df = df.drop(['Remaining_Data'], axis=1)
df.head()
# Out:
#                                Signing_Legis    Legis_Design       Legis_Name  \
# 0            Senator Kevin Ranker Washington         Senator     Kevin Ranker
# 1       Assemblyman Thomas Abinanti New York     Assemblyman  Thomas Abinanti
# 2    Representative John Ager North Carolina  Representative        John Ager
# 3               Senator Ben Allen California         Senator        Ben Allen
# 4  Representative Sherry Appleton Washington  Representative  Sherry Appleton
#
#   Legis_State
# 0          WA
# 1          NY
# 2          NC
# 3          CA
# 4          WA

# %%
### Ignore this box of Code ###
#Some Examples for self reference

a = "Stanley Paige Zeigler"
b = a.split()
concat = b[1] +', '+ b[-1]
''.join(concat)
name = a.split()
name
a = ' '.join(name[:-1])
b = name[-1]
print(a)
print(b)
name[1]
com = b+','+' '+ a
com.strip()
# Out:
# Stanley Paige
# Zeigler
# 'Zeigler, Stanley Paige'

# %%
# Format legislators names in 'Legis_Name' to match it to Shor-Mcarty data
# Save it in 'Formated_Legis_Names'

Formated_Names = []

for name in df["Legis_Name"]:
    name = name.split()
    last_part = name[-1]
    first_part = " ".join(name[:-1])
    concatinate = last_part +', '+first_part
    reversed_name = "".join(concatinate)
    Formated_Names.append(reversed_name.strip())
    
df["Formated_Legis_Names"] = Formated_Names

df.head(10)
# Out:
#                                Signing_Legis    Legis_Design       Legis_Name  \
# 0            Senator Kevin Ranker Washington         Senator     Kevin Ranker
# 1       Assemblyman Thomas Abinanti New York     Assemblyman  Thomas Abinanti
# 2    Representative John Ager North Carolina  Representative        John Ager
# 3               Senator Ben Allen California         Senator        Ben Allen
# 4  Representative Sherry Appleton Washington  Representative  Sherry Appleton
# 5   Representative David Arconti Connecticut  Representative    David Arconti
# 6   Representative John Autry North Carolina  Representative       John Autry
# 7        Representative Phil Barnhart Oregon  Representative    Phil Barnhart
# 8              Chairman Kumar Barve Maryland        Chairman      Kumar Barve
# 9      Representative Paul Baumbach Delaware  Representative    Paul Baumbach
#
#   Legis_State Formated_Legis_Names
# 0          WA        Ranker, Kevin
# 1          NY     Abinanti, Thomas
# 2          NC           Ager, John
# 3          CA           Allen, Ben
# 4          WA     Appleton, Sherry
# 5          CT       Arconti, David
# 6          NC          Autry, John
# 7          OR       Barnhart, Phil
# 8          MD         Barve, Kumar
# 9          DE       Baumbach, Paul

# %%
#Import the Shor-Mcarty dataset

file2 = "/Users/ishitagopal/Box/science_backed_policy_diffusion/Dataset/shor_mcarty_1993_to_2016_with_Id.csv"

fields = ['name', 'party', 'st', 'st_id', 'Legislator_Id']
df2 = pd.read_csv(file2, skipinitialspace = True, usecols = fields)

df2.head()
# Out:
#               name party  st  st_id Legislator_Id
# 0            Adams     R  AL      1          AL_1
# 1  Albritton, Greg     R  AL      2          AL_2
# 2    Allen, Gerald     R  AL      3          AL_3
# 3            Amari     R  AL      4          AL_4
# 4  Armistead, Bill     R  AL      5          AL_5

# %%
# Check if exact matches between the messy names and the Shor-Mcarty dataset were found 

exact_matches = df.Formated_Legis_Names.isin(df2.name)
exact_matches.value_counts()
# Out:
# False    140
# True      85
# Name: Formated_Legis_Names, dtype: int64

# %%
# Create a list of messy names retrieved from the letter. Save in 'wrong_names'

wrong_names=df['Formated_Legis_Names'].values

# Create a list of legislator names from the Shor-Mcarty dataset in 'df2'

correct_names=df2['name'].values

# %%
len(wrong_names)
# Out:
# 225

# %%
# Construct a function 'match_names' to *fuzzy* match the messy names in 'df' to the Shor-Mcarty names in 'df2'
# Return only the best match along with its ratio as 2 lists

names_array = []
ratio_array = []

def match_names(wrong_names,correct_names):
    for row in wrong_names:
        x = process.extractOne(row, correct_names)
        names_array.append(x[0])
        ratio_array.append(x[1])
    return names_array, ratio_array

# %%
#Apply the match_names function which returns two lists : 'name_match' and 'ratio_match'

name_match, ratio_match = match_names(wrong_names, correct_names)

# %%
len(name_match)
len(ratio_match)
# Out:
# 225

# %%
# Store the matched names and their match ratios in 'Fuzzy_Legis_Name' and 'Fuzzy_Legis_Ratio'

df['Fuzzy_Legis_Name'] = pd.Series(name_match)
df['Fuzzy_Legis_Ratio'] = pd.Series(ratio_match)

df.head(10)
# Out:
#                                Signing_Legis    Legis_Design       Legis_Name  \
# 0            Senator Kevin Ranker Washington         Senator     Kevin Ranker
# 1       Assemblyman Thomas Abinanti New York     Assemblyman  Thomas Abinanti
# 2    Representative John Ager North Carolina  Representative        John Ager
# 3               Senator Ben Allen California         Senator        Ben Allen
# 4  Representative Sherry Appleton Washington  Representative  Sherry Appleton
# 5   Representative David Arconti Connecticut  Representative    David Arconti
# 6   Representative John Autry North Carolina  Representative       John Autry
# 7        Representative Phil Barnhart Oregon  Representative    Phil Barnhart
# 8              Chairman Kumar Barve Maryland        Chairman      Kumar Barve
# 9      Representative Paul Baumbach Delaware  Representative    Paul Baumbach
#
#   Legis_State Formated_Legis_Names ExactMatch           Fuzzy_Legis_Name  \
# 0          WA        Ranker, Kevin       True              Ranker, Kevin
# 1          NY     Abinanti, Thomas      False        Abinanti, Thomas J.
# 2          NC           Ager, John      False               Jagler, John
# 3          CA           Allen, Ben       True                 Allen, Ben
# 4          WA     Appleton, Sherry       True           Appleton, Sherry
# 5          CT       Arconti, David      False         Arconti, David Jr.
# 6          NC          Autry, John      False  England, Christopher John
# 7          OR       Barnhart, Phil      False                       Hart
# 8          MD         Barve, Kumar       True               Barve, Kumar
# 9          DE       Baumbach, Paul      False          Baumbach, Paul S.
#
#    Fuzzy_Legis_Ratio
# 0                100
# 1                 95
# 2                 91
# 3                100
# 4                100
# 5                 95
# 6                 86
# 7                 90
# 8                100
# 9                 95

# %%
# Attaching corresponding 'Legislator_ID' from the Shor-Mcarty dataset in 'df2' to the best name matches in 'Fuzzy_Legis_Name'
# Save all the associated IDs found for a name in 'All_Legis_Id_Options'

A = []
B = []
for name in df["Fuzzy_Legis_Name"]:
    unique_ID = df2.loc[df2['name'] == name, 'Legislator_Id'].values
    unique_ID2 = df2.loc[df2['name'] == name, 'Legislator_Id'].iloc[0]
    
    A.append(unique_ID)
    B.append(unique_ID2)

df["All_Legis_Id_Options"] = A
df["1st_Legis_Id_Option"] = B

df.head(50)
# Out:
#                                         Signing_Legis    Legis_Design  \
# 0                     Senator Kevin Ranker Washington         Senator
# 1                Assemblyman Thomas Abinanti New York     Assemblyman
# 2             Representative John Ager North Carolina  Representative
# 3                        Senator Ben Allen California         Senator
# 4           Representative Sherry Appleton Washington  Representative
# 5            Representative David Arconti Connecticut  Representative
# 6            Representative John Autry North Carolina  Representative
# 7                 Representative Phil Barnhart Oregon  Representative
# 8                       Chairman Kumar Barve Maryland        Chairman
# 9               Representative Paul Baumbach Delaware  Representative
# 10            Representative Mary Belk North Carolina  Representative
# 11                       Senator Shenna Bellows Maine         Senator
# 12               Assemblyman Daniel Benson New Jersey     Assemblyman
# 13       Representative Jennifer Benson Massachusetts  Representative
# 14                 Representative Lori Berman Florida  Representative
# 15                    Representative Seth Berry Maine  Representative
# 16                     Senator Andy Billig Washington         Senator
# 17                Representative Deborah Boone Oregon  Representative
# 18                  Delegate Jennifer Boysko Virginia        Delegate
# 19                          Senator Cathy Breen Maine         Senator
# 20       Representative Cecil Brockman North Carolina  Representative
# 21         Representative Robert Brown South Carolina  Representative
# 22                Assemblyman David Buchwald New York     Assemblyman
# 23           Representative Deb Butler North Carolina  Representative
# 24                Senator Jeanine Calkin Rhode Island         Senator
# 25                  Senator Reuven Carlyle Washington         Senator
# 26                          Delegate Al Carr Maryland        Delegate
# 27          Representative Lauren Carson Rhode Island  Representative
# 28                       Senator Stanley Chang Hawaii         Senator
# 29             Representative Mike Chapman Washington  Representative
# 30                   Senator Maralyn Chase Washington         Senator
# 31              Representative Eileen Cody Washington  Representative
# 32                 Assemblyman Herb Conway New Jersey     Assemblyman
# 33                 Representative Janice Cooper Maine  Representative
# 34              Representative Richard Creagan Hawaii  Representative
# 35                   Senator Julian Cyr Massachusetts         Senator
# 36                Senator Jeannie Dameille Washington         Senator
# 37              Representative Matthea Daughtry Maine  Representative
# 38                     Senator Michael Dembrow Oregon         Senator
# 39                 Representative Michael Devin Maine  Representative
# 40                   Senator Manka Dhingra Washington         Senator
# 41                 Senator Patrick Diegnan New Jersey         Senator
# 42              Assemblyman Jeffrey Dinowitz New York     Assemblyman
# 43             Representative Laurie Dolan Washington  Representative
# 44          Representative Susan Donovan Rhode Island  Representative
# 45       Representative Michelle DuBois Massachusetts  Representative
# 46          Assemblymember Steve Englebright New York  Assemblymember
# 47                   Representative Paul Evans Oregon  Representative
# 48                  Representative Julie Fahey Oregon  Representative
# 49  Representative Jean Farmer-Butterfield North C...  Representative
#
#                  Legis_Name Legis_State      Formated_Legis_Names ExactMatch  \
# 0              Kevin Ranker          WA             Ranker, Kevin       True
# 1           Thomas Abinanti          NY          Abinanti, Thomas      False
# 2                 John Ager          NC                Ager, John      False
# 3                 Ben Allen          CA                Allen, Ben       True
# 4           Sherry Appleton          WA          Appleton, Sherry       True
# 5             David Arconti          CT            Arconti, David      False
# 6                John Autry          NC               Autry, John      False
# 7             Phil Barnhart          OR            Barnhart, Phil      False
# 8               Kumar Barve          MD              Barve, Kumar       True
# 9             Paul Baumbach          DE            Baumbach, Paul      False
# 10                Mary Belk          NC                Belk, Mary      False
# 11           Shenna Bellows          ME           Bellows, Shenna      False
# 12            Daniel Benson          NJ            Benson, Daniel      False
# 13          Jennifer Benson          MA          Benson, Jennifer      False
# 14              Lori Berman          FL              Berman, Lori       True
# 15               Seth Berry          ME               Berry, Seth       True
# 16              Andy Billig          WA              Billig, Andy       True
# 17            Deborah Boone          OR            Boone, Deborah       True
# 18          Jennifer Boysko          VA          Boysko, Jennifer       True
# 19              Cathy Breen          ME              Breen, Cathy      False
# 20           Cecil Brockman          NC           Brockman, Cecil      False
# 21             Robert Brown          SC             Brown, Robert       True
# 22           David Buchwald          NY           Buchwald, David       True
# 23               Deb Butler          NC               Butler, Deb      False
# 24           Jeanine Calkin          RI           Calkin, Jeanine      False
# 25           Reuven Carlyle          WA           Carlyle, Reuven       True
# 26                  Al Carr          MD                  Carr, Al      False
# 27            Lauren Carson          RI            Carson, Lauren      False
# 28            Stanley Chang          HI            Chang, Stanley      False
# 29             Mike Chapman          WA             Chapman, Mike      False
# 30            Maralyn Chase          WA            Chase, Maralyn       True
# 31              Eileen Cody          WA              Cody, Eileen      False
# 32              Herb Conway          NJ              Conway, Herb      False
# 33            Janice Cooper          ME            Cooper, Janice       True
# 34          Richard Creagan          HI          Creagan, Richard      False
# 35               Julian Cyr          MA               Cyr, Julian      False
# 36         Jeannie Dameille          WA         Dameille, Jeannie      False
# 37         Matthea Daughtry          ME         Daughtry, Matthea      False
# 38          Michael Dembrow          OR          Dembrow, Michael      False
# 39            Michael Devin          ME            Devin, Michael      False
# 40            Manka Dhingra          WA            Dhingra, Manka      False
# 41          Patrick Diegnan          NJ          Diegnan, Patrick      False
# 42         Jeffrey Dinowitz          NY         Dinowitz, Jeffrey       True
# 43             Laurie Dolan          WA             Dolan, Laurie      False
# 44            Susan Donovan          RI            Donovan, Susan      False
# 45          Michelle DuBois          MA          DuBois, Michelle      False
# 46        Steve Englebright          NY        Englebright, Steve      False
# 47               Paul Evans          OR               Evans, Paul       True
# 48              Julie Fahey          OR              Fahey, Julie      False
# 49  Jean Farmer-Butterfield          NC  Farmer-Butterfield, Jean       True
#
#                  Fuzzy_Legis_Name  Fuzzy_Legis_Ratio  \
# 0                   Ranker, Kevin                100
# 1             Abinanti, Thomas J.                 95
# 2                    Jagler, John                 91
# 3                      Allen, Ben                100
# 4                Appleton, Sherry                100
# 5              Arconti, David Jr.                 95
# 6       England, Christopher John                 86
# 7                            Hart                 90
# 8                    Barve, Kumar                100
# 9               Baumbach, Paul S.                 95
# 10            McClurkin, Mary Sue                 86
# 11                           Bell                 90
# 12               Benson, Daniel R                 95
# 13                         Benson                 90
# 14                   Berman, Lori                100
# 15                    Berry, Seth                100
# 16                   Billig, Andy                100
# 17                 Boone, Deborah                100
# 18               Boysko, Jennifer                100
# 19        McMorris Rodgers, Cathy                 86
# 20                          Brock                 90
# 21                  Brown, Robert                100
# 22                Buchwald, David                100
# 23             Butler, Timothy J.                 86
# 24                  Long, Jeanine                 79
# 25                Carlyle, Reuven                100
# 26               Carr, Alfred Jr.                 90
# 27              Carson, Lauren H.                 95
# 28         Stanley-Turner, LaNett                 86
# 29     Chapman, Kathleen Halloran                 86
# 30                 Chase, Maralyn                100
# 31                 Cody, Eileen L                 95
# 32                         Conway                 90
# 33                 Cooper, Janice                100
# 34                         Reagan                 90
# 35                         Uliana                 82
# 36             Darneille, Jeannie                 91
# 37     Larsen Daughtry, Matthea E                 90
# 38            Dembrow, Michael E.                 95
# 39         Devin, Michael Gilbert                 90
# 40                           King                 68
# 41          Diegnan Jr, Patrick J                 95
# 42              Dinowitz, Jeffrey                100
# 43                          Dolan                 90
# 44       Hamilton, Susan Holladay                 86
# 45  Rehwinkel Vasilinda, Michelle                 86
# 46            Englebright, Steven                 97
# 47                    Evans, Paul                100
# 48             Fahey, John Edward                 86
# 49       Farmer-Butterfield, Jean                100
#
#                 All_Legis_Id_Options 1st_Legis_Id_Option
# 0                           [WA_120]              WA_120
# 1                           [NY_162]              NY_162
# 2                           [WI_179]              WI_179
# 3               [AR_1, CA_4, GA_258]                AR_1
# 4                           [WA_173]              WA_173
# 5                           [CT_103]              CT_103
# 6                           [AL_149]              AL_149
# 7                            [CA_62]               CA_62
# 8                           [MD_138]              MD_138
# 9                            [DE_50]               DE_50
# 10                          [AL_250]              AL_250
# 11            [OK_8, TN_105, WI_101]                OK_8
# 12                          [NJ_118]              NJ_118
# 13                           [SD_10]               SD_10
# 14                          [FL_169]              FL_169
# 15                          [ME_178]              ME_178
# 16                           [WA_14]               WA_14
# 17                           [OR_99]               OR_99
# 18                          [VA_130]              VA_130
# 19                          [WA_377]              WA_377
# 20                          [AZ_169]              AZ_169
# 21                           [GA_27]               GA_27
# 22                          [NY_202]              NY_202
# 23                          [IL_197]              IL_197
# 24                           [WA_82]               WA_82
# 25                           [WA_22]               WA_22
# 26                          [MD_170]              MD_170
# 27                          [RI_157]              RI_157
# 28                          [GA_830]              GA_830
# 29                          [IA_253]              IA_253
# 30                           [WA_24]               WA_24
# 31                          [WA_221]              WA_221
# 32                           [NE_35]               NE_35
# 33                          [ME_253]              ME_253
# 34                           [NM_74]               NM_74
# 35                           [PA_99]               PA_99
# 36                           [WA_32]               WA_32
# 37                          [ME_458]              ME_458
# 38                           [OR_22]               OR_22
# 39                          [ME_278]              ME_278
# 40  [AZ_248, KS_314, NM_202, PA_328]              AZ_248
# 41                          [NJ_165]              NJ_165
# 42                          [NY_251]              NY_251
# 43                          [MI_232]              MI_232
# 44                          [NC_304]              NC_304
# 45                          [FL_438]              FL_438
# 46                          [NY_257]              NY_257
# 47          [IL_242, IL_243, OR_125]              IL_242
# 48                          [WV_169]              WV_169
# 49                          [NC_269]              NC_269

# %%
## Ignore this box ##
#Usefull Link to deal with paste warnings: https://www.youtube.com/watch?v=4R4WsDJ-KVc

# %%
# Create a dataframe where match ratio is >=95 (Likely correct matches)

df3 = df.loc[df['Fuzzy_Legis_Ratio']>=95,:].copy()

# Create dataframes where match ratio < 95 (Likely incorrect matches)

df4 = df.loc[df['Fuzzy_Legis_Ratio']<95,:].copy()

# %%
print(len(df3))
df3.head(10)
# Out:
# 134
#                                 Signing_Legis    Legis_Design  \
# 0             Senator Kevin Ranker Washington         Senator
# 1        Assemblyman Thomas Abinanti New York     Assemblyman
# 3                Senator Ben Allen California         Senator
# 4   Representative Sherry Appleton Washington  Representative
# 5    Representative David Arconti Connecticut  Representative
# 8               Chairman Kumar Barve Maryland        Chairman
# 9       Representative Paul Baumbach Delaware  Representative
# 12       Assemblyman Daniel Benson New Jersey     Assemblyman
# 14         Representative Lori Berman Florida  Representative
# 15            Representative Seth Berry Maine  Representative
#
#          Legis_Name Legis_State Formated_Legis_Names ExactMatch  \
# 0      Kevin Ranker          WA        Ranker, Kevin       True
# 1   Thomas Abinanti          NY     Abinanti, Thomas      False
# 3         Ben Allen          CA           Allen, Ben       True
# 4   Sherry Appleton          WA     Appleton, Sherry       True
# 5     David Arconti          CT       Arconti, David      False
# 8       Kumar Barve          MD         Barve, Kumar       True
# 9     Paul Baumbach          DE       Baumbach, Paul      False
# 12    Daniel Benson          NJ       Benson, Daniel      False
# 14      Lori Berman          FL         Berman, Lori       True
# 15       Seth Berry          ME          Berry, Seth       True
#
#        Fuzzy_Legis_Name  Fuzzy_Legis_Ratio  All_Legis_Id_Options  \
# 0         Ranker, Kevin                100              [WA_120]
# 1   Abinanti, Thomas J.                 95              [NY_162]
# 3            Allen, Ben                100  [AR_1, CA_4, GA_258]
# 4      Appleton, Sherry                100              [WA_173]
# 5    Arconti, David Jr.                 95              [CT_103]
# 8          Barve, Kumar                100              [MD_138]
# 9     Baumbach, Paul S.                 95               [DE_50]
# 12     Benson, Daniel R                 95              [NJ_118]
# 14         Berman, Lori                100              [FL_169]
# 15          Berry, Seth                100              [ME_178]
#
#    1st_Legis_Id_Option
# 0               WA_120
# 1               NY_162
# 3                 AR_1
# 4               WA_173
# 5               CT_103
# 8               MD_138
# 9                DE_50
# 12              NJ_118
# 14              FL_169
# 15              ME_178

# %%
print(len(df4))
df4.head(10)
# Out:
# 91
#                                    Signing_Legis    Legis_Design  \
# 2        Representative John Ager North Carolina  Representative
# 6       Representative John Autry North Carolina  Representative
# 7            Representative Phil Barnhart Oregon  Representative
# 10       Representative Mary Belk North Carolina  Representative
# 11                  Senator Shenna Bellows Maine         Senator
# 13  Representative Jennifer Benson Massachusetts  Representative
# 19                     Senator Cathy Breen Maine         Senator
# 20  Representative Cecil Brockman North Carolina  Representative
# 23      Representative Deb Butler North Carolina  Representative
# 24           Senator Jeanine Calkin Rhode Island         Senator
#
#          Legis_Name Legis_State Formated_Legis_Names ExactMatch  \
# 2         John Ager          NC           Ager, John      False
# 6        John Autry          NC          Autry, John      False
# 7     Phil Barnhart          OR       Barnhart, Phil      False
# 10        Mary Belk          NC           Belk, Mary      False
# 11   Shenna Bellows          ME      Bellows, Shenna      False
# 13  Jennifer Benson          MA     Benson, Jennifer      False
# 19      Cathy Breen          ME         Breen, Cathy      False
# 20   Cecil Brockman          NC      Brockman, Cecil      False
# 23       Deb Butler          NC          Butler, Deb      False
# 24   Jeanine Calkin          RI      Calkin, Jeanine      False
#
#              Fuzzy_Legis_Name  Fuzzy_Legis_Ratio    All_Legis_Id_Options  \
# 2                Jagler, John                 91                [WI_179]
# 6   England, Christopher John                 86                [AL_149]
# 7                        Hart                 90                 [CA_62]
# 10        McClurkin, Mary Sue                 86                [AL_250]
# 11                       Bell                 90  [OK_8, TN_105, WI_101]
# 13                     Benson                 90                 [SD_10]
# 19    McMorris Rodgers, Cathy                 86                [WA_377]
# 20                      Brock                 90                [AZ_169]
# 23         Butler, Timothy J.                 86                [IL_197]
# 24              Long, Jeanine                 79                 [WA_82]
#
#    1st_Legis_Id_Option
# 2               WI_179
# 6               AL_149
# 7                CA_62
# 10              AL_250
# 11                OK_8
# 13               SD_10
# 19              WA_377
# 20              AZ_169
# 23              IL_197
# 24               WA_82

# %%
# While going through the matches for the matched names in df4 (where the ratio is <95) 
#I find that the second best match is better 

# So I use the match_names function and store the second best name option as well
# Out:
# array(['Ager, John', 'Autry, John', 'Barnhart, Phil', 'Belk, Mary',
#        'Bellows, Shenna'], dtype=object)

# %%
# Creating List of messy names in df4 and store it in 'wrong_names2'
# Correct_names stays the same 

wrong_names2 = df4["Formated_Legis_Names"].values
wrong_names2[:5]
# Out:
# array(['Ager, John', 'Autry, John', 'Barnhart, Phil', 'Belk, Mary',
#        'Bellows, Shenna'], dtype=object)

# %%
# Create a match function 'match_second_best_names' which stores the second best predicted name and its associated ratio 

names_array2 = []
ratio_array2 = []

def match_second_best_names(wrong_names2, correct_names,limit=2):
    for row in wrong_names2:
        x = process.extract(row, correct_names, limit=limit)
        names_array2.append(x[1][0])
        ratio_array2.append(x[1][1])
    return names_array2, ratio_array2

# %%
# Apply the match_names_second_best function to wrong_names2

name_match2, ratio_match2 = match_second_best_names(wrong_names2, correct_names)

# %%
# Store the second best predicted legislator name in 'Fuzzy_Legis_Name2'

df4["Fuzzy_Legis_Name2"] = name_match2
df4["Fuzzy_Legis_Ratio2"] = ratio_match2
df4.head(10)
# Out:
#                                    Signing_Legis    Legis_Design  \
# 2        Representative John Ager North Carolina  Representative
# 6       Representative John Autry North Carolina  Representative
# 7            Representative Phil Barnhart Oregon  Representative
# 10       Representative Mary Belk North Carolina  Representative
# 11                  Senator Shenna Bellows Maine         Senator
# 13  Representative Jennifer Benson Massachusetts  Representative
# 19                     Senator Cathy Breen Maine         Senator
# 20  Representative Cecil Brockman North Carolina  Representative
# 23      Representative Deb Butler North Carolina  Representative
# 24           Senator Jeanine Calkin Rhode Island         Senator
#
#          Legis_Name Legis_State Formated_Legis_Names ExactMatch  \
# 2         John Ager          NC           Ager, John      False
# 6        John Autry          NC          Autry, John      False
# 7     Phil Barnhart          OR       Barnhart, Phil      False
# 10        Mary Belk          NC           Belk, Mary      False
# 11   Shenna Bellows          ME      Bellows, Shenna      False
# 13  Jennifer Benson          MA     Benson, Jennifer      False
# 19      Cathy Breen          ME         Breen, Cathy      False
# 20   Cecil Brockman          NC      Brockman, Cecil      False
# 23       Deb Butler          NC          Butler, Deb      False
# 24   Jeanine Calkin          RI      Calkin, Jeanine      False
#
#              Fuzzy_Legis_Name  Fuzzy_Legis_Ratio    All_Legis_Id_Options  \
# 2                Jagler, John                 91                [WI_179]
# 6   England, Christopher John                 86                [AL_149]
# 7                        Hart                 90                 [CA_62]
# 10        McClurkin, Mary Sue                 86                [AL_250]
# 11                       Bell                 90  [OK_8, TN_105, WI_101]
# 13                     Benson                 90                 [SD_10]
# 19    McMorris Rodgers, Cathy                 86                [WA_377]
# 20                      Brock                 90                [AZ_169]
# 23         Butler, Timothy J.                 86                [IL_197]
# 24              Long, Jeanine                 79                 [WA_82]
#
#    1st_Legis_Id_Option          Fuzzy_Legis_Name2  Fuzzy_Legis_Ratio2
# 2               WI_179          Ager, John Curtis                  90
# 6               AL_149          Rogers Jr, John W                  86
# 7                CA_62        Barnhart, Philip N.                  88
# 10              AL_250            Broadaway, Mary                  86
# 11                OK_8                       Bell                  90
# 13               SD_10  Bertino-Tarrant, Jennifer                  86
# 19              WA_377           Breen, Catherine                  79
# 20              AZ_169                       Rock                  90
# 23              IL_197      Butler Dixon, Deborah                  86
# 24               WA_82                   Akin, W.                  77

# %%
#Attaching Legislator ID to the second best names found 

A_ = []
B_ = []

for name in df4["Fuzzy_Legis_Name2"]:
    unique_ID = df2.loc[df2['name'] == name, 'Legislator_Id'].values
    unique_ID2 = df2.loc[df2['name'] == name, 'Legislator_Id'].iloc[0]
    
    A_.append(unique_ID)
    B_.append(unique_ID2)

df4["All_Legis_Id_Options2"] = A_
df4["1st_Legis_Id_Option2"] = B_

df4.head(20)
# Out:
#                                    Signing_Legis    Legis_Design  \
# 2        Representative John Ager North Carolina  Representative
# 6       Representative John Autry North Carolina  Representative
# 7            Representative Phil Barnhart Oregon  Representative
# 10       Representative Mary Belk North Carolina  Representative
# 11                  Senator Shenna Bellows Maine         Senator
# 13  Representative Jennifer Benson Massachusetts  Representative
# 19                     Senator Cathy Breen Maine         Senator
# 20  Representative Cecil Brockman North Carolina  Representative
# 23      Representative Deb Butler North Carolina  Representative
# 24           Senator Jeanine Calkin Rhode Island         Senator
# 26                     Delegate Al Carr Maryland        Delegate
# 28                  Senator Stanley Chang Hawaii         Senator
# 29        Representative Mike Chapman Washington  Representative
# 32            Assemblyman Herb Conway New Jersey     Assemblyman
# 34         Representative Richard Creagan Hawaii  Representative
# 35              Senator Julian Cyr Massachusetts         Senator
# 36           Senator Jeannie Dameille Washington         Senator
# 37         Representative Matthea Daughtry Maine  Representative
# 39            Representative Michael Devin Maine  Representative
# 40              Senator Manka Dhingra Washington         Senator
#
#           Legis_Name Legis_State Formated_Legis_Names ExactMatch  \
# 2          John Ager          NC           Ager, John      False
# 6         John Autry          NC          Autry, John      False
# 7      Phil Barnhart          OR       Barnhart, Phil      False
# 10         Mary Belk          NC           Belk, Mary      False
# 11    Shenna Bellows          ME      Bellows, Shenna      False
# 13   Jennifer Benson          MA     Benson, Jennifer      False
# 19       Cathy Breen          ME         Breen, Cathy      False
# 20    Cecil Brockman          NC      Brockman, Cecil      False
# 23        Deb Butler          NC          Butler, Deb      False
# 24    Jeanine Calkin          RI      Calkin, Jeanine      False
# 26           Al Carr          MD             Carr, Al      False
# 28     Stanley Chang          HI       Chang, Stanley      False
# 29      Mike Chapman          WA        Chapman, Mike      False
# 32       Herb Conway          NJ         Conway, Herb      False
# 34   Richard Creagan          HI     Creagan, Richard      False
# 35        Julian Cyr          MA          Cyr, Julian      False
# 36  Jeannie Dameille          WA    Dameille, Jeannie      False
# 37  Matthea Daughtry          ME    Daughtry, Matthea      False
# 39     Michael Devin          ME       Devin, Michael      False
# 40     Manka Dhingra          WA       Dhingra, Manka      False
#
#               Fuzzy_Legis_Name  Fuzzy_Legis_Ratio  \
# 2                 Jagler, John                 91
# 6    England, Christopher John                 86
# 7                         Hart                 90
# 10         McClurkin, Mary Sue                 86
# 11                        Bell                 90
# 13                      Benson                 90
# 19     McMorris Rodgers, Cathy                 86
# 20                       Brock                 90
# 23          Butler, Timothy J.                 86
# 24               Long, Jeanine                 79
# 26            Carr, Alfred Jr.                 90
# 28      Stanley-Turner, LaNett                 86
# 29  Chapman, Kathleen Halloran                 86
# 32                      Conway                 90
# 34                      Reagan                 90
# 35                      Uliana                 82
# 36          Darneille, Jeannie                 91
# 37  Larsen Daughtry, Matthea E                 90
# 39      Devin, Michael Gilbert                 90
# 40                        King                 68
#
#                 All_Legis_Id_Options 1st_Legis_Id_Option  \
# 2                           [WI_179]              WI_179
# 6                           [AL_149]              AL_149
# 7                            [CA_62]               CA_62
# 10                          [AL_250]              AL_250
# 11            [OK_8, TN_105, WI_101]                OK_8
# 13                           [SD_10]               SD_10
# 19                          [WA_377]              WA_377
# 20                          [AZ_169]              AZ_169
# 23                          [IL_197]              IL_197
# 24                           [WA_82]               WA_82
# 26                          [MD_170]              MD_170
# 28                          [GA_830]              GA_830
# 29                          [IA_253]              IA_253
# 32                           [NE_35]               NE_35
# 34                           [NM_74]               NM_74
# 35                           [PA_99]               PA_99
# 36                           [WA_32]               WA_32
# 37                          [ME_458]              ME_458
# 39                          [ME_278]              ME_278
# 40  [AZ_248, KS_314, NM_202, PA_328]              AZ_248
#
#             Fuzzy_Legis_Name2  Fuzzy_Legis_Ratio2   All_Legis_Id_Options2  \
# 2           Ager, John Curtis                  90                [NC_162]
# 6           Rogers Jr, John W                  86                [AL_295]
# 7         Barnhart, Philip N.                  88                 [OR_92]
# 10            Broadaway, Mary                  86                [AR_196]
# 11                       Bell                  90  [OK_8, TN_105, WI_101]
# 13  Bertino-Tarrant, Jennifer                  86                  [IL_8]
# 19           Breen, Catherine                  79                 [ME_17]
# 20                       Rock                  90                 [KS_99]
# 23      Butler Dixon, Deborah                  86                [MS_184]
# 24                   Akin, W.                  77                [MO_131]
# 26                 Carr, Dale                  89                [TN_130]
# 28      Weaver, Stanley Blake                  86                [IL_150]
# 29   Smith, Kenneth M. "Mike"                  86                [LA_118]
# 32                        Way                  90                [VA_344]
# 34   Perkins, Anthony Richard                  86                [LA_341]
# 35            Carroll, Julian                  77                 [KY_10]
# 36                   Lee, Jan                  79        [OR_179, OR_180]
# 37                   Matthews                  72        [SD_295, UT_277]
# 39    Feeley, Michael Francis                  86                 [CO_33]
# 40                       Mack                  68                 [DE_96]
#
#    1st_Legis_Id_Option2
# 2                NC_162
# 6                AL_295
# 7                 OR_92
# 10               AR_196
# 11                 OK_8
# 13                 IL_8
# 19                ME_17
# 20                KS_99
# 23               MS_184
# 24               MO_131
# 26               TN_130
# 28               IL_150
# 29               LA_118
# 32               VA_344
# 34               LA_341
# 35                KY_10
# 36               OR_179
# 37               SD_295
# 39                CO_33
# 40                DE_96

# %%
df3 = df3.sort_values(by=['Fuzzy_Legis_Ratio'],ascending=False)

# %%
df3.to_csv("/Users/ishitagopal/Desktop/df3_95_to_100.csv")

# %%
df4.to_csv("/Users/ishitagopal/Desktop/df3_below_95.csv")

# %%
## Function to test single names ###

def match_single_names(wrong_name, correct_names, limit):
    result = process.extract(wrong_name, correct_names, limit=limit)
    return result

# %%
match_single_names('Dhingra, Manka', correct_names,10)
# Out:
# [('King', 68),
#  ('Mack', 68),
#  ('King', 68),
#  ('Gray', 68),
#  ('King', 68),
#  ('King', 68),
#  ('Sinagra, Jack', 67),
#  ('Diaz, Manny', 64),
#  ('Ma, Fiona', 64),
#  ('Chang, Mark', 64)]

# %% [raw]
# '''Manka Dhingra is an Indian-American attorney and politician who is a Washington State senator.
# She was elected to represent the 45th legislative district, on Seattle's Eastside in King County,
# during a 2017 special election. Dhingra is the first Sikh elected to any state legislature in the United States'''

# %%
match_single_names("Creagan, Richard",correct_names,10)
# Out:
# [('Reagan', 90),
#  ('Perkins, Anthony Richard', 86),
#  ('Garcia Richard, Stephanie', 86),
#  ('Browning, Dwight Richard', 86),
#  ('Richards', 84),
#  ('Morgan, Richard', 84),
#  ('Hardt', 80),
#  ('Carey, Richard', 80),
#  ('Rosen, Richard', 80),
#  ('Cebra, Richard', 80)]

# %% [raw]
# Tenure 2014 - Present Term ends 2020, Years in position 5, Democratic Party
# https://ballotpedia.org/Richard_Creagan

# %%
match_single_names("Cyr, Julian",correct_names,10)
# Out:
# [('Uliana', 82),
#  ('Carroll, Julian', 77),
#  ('Lynn, Julia', 73),
#  ('Cryor, Jean', 73),
#  ('Julian, Patti', 71),
#  ('Fant III, Julian', 71),
#  ('Bond, Julian', 71),
#  ('Garrett, Julian', 71),
#  ('Julian, Larry', 71),
#  ('Curry, Julie', 70)]

# %% [raw]
# Julian Andre Cyr is an American politician, who was elected to the Massachusetts State Senate in 2016. A Democrat, he represents the Cape and Islands district.
